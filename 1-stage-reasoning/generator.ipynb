# %%
# !git clone https://github.com/NitinSudarsanam/chained-adversarial-reasoning.git
# Out:
# fatal: destination path 'chained-adversarial-reasoning' already exists and is not an empty directory.

# %%
# %cd chained-adversarial-reasoning/
# Out:
# /content/chained-adversarial-reasoning

# %%
# !pip install torch transformers accelerate tqdm bitsandbytes peft -q

# %%
# !pip install huggingface_hub
from huggingface_hub import login
login()
# Out:
# Requirement already satisfied: huggingface_hub in /usr/local/lib/python3.12/dist-packages (0.36.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (3.20.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2025.3.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (6.0.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (4.15.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface_hub) (1.2.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->huggingface_hub) (2025.11.12)
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
import torch
import re
from typing import List
from transformers import AutoModelForCausalLM, AutoTokenizer, BitsAndBytesConfig
from peft import prepare_model_for_kbit_training, LoraConfig, get_peft_model

# %%
"""Generator LLM for producing multi-stage reasoning and code."""

# ONLY LLAMA 3.1 8B SUPPORTED RIGHT NOW
class GenericLLM:
    def __init__(self, model, tokenizer, model_name, SYSTEM_PROMPT, device: str = "cuda"):
        """Initialize generator from HuggingFace model.

        Args:
            model_name: HuggingFace model identifier
            device: Device to run on ('cpu' or 'cuda')
        """
        self.model_name = model_name
        self.device = device
        self.tokenizer = tokenizer
        self.SYSTEM_PROMPT = SYSTEM_PROMPT

        print(f"Loading generator model: {model_name}")

        peft_config = LoraConfig(
            r=16,
            lora_alpha=32,
            lora_dropout=0.05,
            bias="none",
            task_type="CAUSAL_LM",
            target_modules=[
                "q_proj",
                "k_proj",
                "v_proj",
                "o_proj",
                "gate_proj",
                "up_proj",
                "down_proj",
            ],
        )

        base_model = prepare_model_for_kbit_training(model)
        self.model = get_peft_model(base_model, peft_config)

        for name, param in self.model.named_parameters():
            if "lora_" in name:
                param.requires_grad = True
            else:
                param.requires_grad = False

        self.model.eval()

        # Set pad token if not set
        if self.tokenizer.pad_token is None:
            self.tokenizer.pad_token = self.tokenizer.eos_token


    def train(self):
        """Set model to training mode."""
        self.model.training = True
        self.model.train()

    def activate_lora(self):
        for name, param in self.model.named_parameters():
            if "lora_" in name:
                param.requires_grad = True

    def deactivate_lora(self):
        for name, param in self.model.named_parameters():
            if "lora_" in name:
                param.requires_grad = False

    def eval(self):
        """Set model to evaluation mode."""
        self.model.training = False
        self.model.eval()

    def parameters(self):
        """Return model parameters for optimizer."""
        # return self.model.parameters()
        return [param for name, param in self.model.named_parameters() if "lora_" in name]

    def generate_code(
        self,
        prompt,
        max_new_tokens: int = 2048,
        temperature: float = 0.8,
        top_p: float = 0.9,
    ) -> str:
        """Generate code given the problem.

        Returns:
            Generated Python code
        """

        output = self._generate(prompt, 2048, 0.8, 0.9)

        # Extract code from markdown if present
        output = self._extract_code_from_markdown(output)

        # Additional cleaning for code
        # output = self._clean_generated_code(output)

        output = output.replace("\t", "    ")
        # output = output.replace("List", "list")
        return output # to fix typing inconsistency with newer python versions

    def get_log_probs(self, prompt: str, output: str) -> torch.Tensor:
        """Get log probabilities for RL training.

        Args:
            prompt: Input prompt
            output: Generated output

        Returns:
            Log probabilities tensor
        """
        # Handle empty output
        if not output or not output.strip():
            return torch.tensor([0.0], device=self.device, requires_grad=True)

        # Tokenize with reasonable max length
        full_text = prompt + output
        inputs = self.tokenizer(full_text, return_tensors="pt", truncation=True, max_length=4096).to(self.device)
        prompt_inputs = self.tokenizer(prompt, return_tensors="pt", truncation=True, max_length=4096).to(self.device)

        # Get model outputs (WITH gradients for training)
        outputs = self.model(**inputs) # allocates a whole bunch of memory?
        logits = outputs.logits

        # Get log probs for generated tokens only
        prompt_len = prompt_inputs.input_ids.shape[1]
        input_len = inputs.input_ids.shape[1]

        # Handle edge case where output is too short
        if input_len <= prompt_len:
            del inputs, logits, prompt_inputs
            return torch.tensor([0.0], device=self.device, requires_grad=True)

        generated_logits = logits[0, prompt_len-1:-1, :]
        generated_tokens = inputs.input_ids[0, prompt_len:]

        # Delete inputs now that we've extracted what we need
        del inputs

        # Handle empty generation
        if generated_tokens.shape[0] == 0:
            del logits, generated_logits, generated_tokens, prompt_inputs
            return torch.tensor([0.0], device=self.device, requires_grad=True)

        # Compute log probabilities
        log_probs = torch.nn.functional.log_softmax(generated_logits, dim=-1)
        token_log_probs = log_probs.gather(1, generated_tokens.unsqueeze(1)).squeeze(1)

        # Clean up intermediate tensors
        del logits, generated_logits, generated_tokens, log_probs, prompt_inputs

        return token_log_probs

    def _generate(
        self,
        prompt: str,
        max_new_tokens: int,
        temperature: float,
        top_p: float
    ) -> str:
        """Internal generation method.

        Args:
            prompt: Input prompt
            max_new_tokens: Maximum tokens to generate
            temperature: Sampling temperature
            top_p: Nucleus sampling parameter

        Returns:
            Generated text
        """
        # CRITICAL: Always set to eval mode before generation
        was_training = self.model.training
        self.model.eval()

        # Format prompt using chat template for instruction-tuned models
        messages = [
            {"role": "system", "content": self.SYSTEM_PROMPT},
            {"role": "user", "content": prompt}
        ]
        formatted_prompt = self.tokenizer.apply_chat_template(
            messages,
            tokenize=False,
            add_generation_prompt=True
        )

        inputs = self.tokenizer(formatted_prompt, return_tensors="pt", truncation=True, max_length=4096).to(self.device)

        # Clamp temperature to safe range to avoid numerical issues
        temperature = max(0.1, min(2.0, temperature))
        top_p = max(0.1, min(1.0, top_p))

        with torch.no_grad():
            try:
                outputs = self.model.generate(
                    **inputs,
                    max_new_tokens=max_new_tokens,
                    temperature=temperature,
                    top_p=top_p,
                    do_sample=True,
                    pad_token_id=self.tokenizer.pad_token_id,
                    eos_token_id=self.tokenizer.eos_token_id,
                    repetition_penalty=1.1,  # Prevent repetition issues
                    no_repeat_ngram_size=3   # Prevent exact repetitions
                )
            except Exception as e:
                # If generation fails, return empty string to skip this example
                print(f"Warning: Generation failed with error: {type(e).__name__}: {str(e)[:100]}")
                # Restore training mode if needed
                if was_training:
                    self.model.train()
                # Don't try to use CUDA operations after CUDA error - just return empty
                return ""

        # Decode only the generated part
        generated_tokens = outputs[0][inputs.input_ids.shape[1]:]
        generated_text = self.tokenizer.decode(generated_tokens, skip_special_tokens=True)

        # Restore training mode if it was on before
        if was_training:
            self.model.train()

        return generated_text

    def _extract_code_from_markdown(self, text: str) -> str:
        """Extract code from markdown code blocks.

        Args:
            text: Text potentially containing markdown code blocks

        Returns:
            Extracted code or original text
        """
        # Look for ```python ... ``` blocks (closed)
        pattern = r'```python\s*(.*?)\s*```'
        matches = re.findall(pattern, text, re.DOTALL)

        if matches:
            return matches[0].strip()

        # Look for ``` python ... ``` blocks (closed)
        pattern = r'``` python\s*(.*?)\s*```'
        matches = re.findall(pattern, text, re.DOTALL)

        if matches:
            return matches[0].strip()

        # Look for ``` ... ``` blocks (closed)
        pattern = r'```\s*(.*?)\s*```'
        matches = re.findall(pattern, text, re.DOTALL)

        if matches:
            return matches[0].strip()

        # Look for unclosed ```python blocks (model didn't close it)
        if '```python' in text:
            # Extract everything after ```python
            code = text.split('```python', 1)[1]
            # Remove trailing ``` if present
            code = code.split('```')[0]
            return code.strip()

        # Look for unclosed ``` blocks
        if '```' in text:
            # Extract everything after first ```
            code = text.split('```', 1)[1]
            # Remove trailing ``` if present
            code = code.split('```')[0]
            return code.strip()

        return text.strip()

# %%
model_name = "meta-llama/Llama-3.1-8B-Instruct"
tokenizer = AutoTokenizer.from_pretrained(model_name)

quant_config = BitsAndBytesConfig(
            load_in_4bit=True,
            bnb_4bit_quant_type="nf4",
            bnb_4bit_compute_dtype=torch.bfloat16,
            bnb_4bit_use_double_quant=True,
        )

model = AutoModelForCausalLM.from_pretrained(
    model_name,
    device_map="cuda",
    quantization_config=quant_config,
    # use_cache=False
)
# Out:
# Loading checkpoint shards:   0%|          | 0/4 [00:00<?, ?it/s]

# %%
GENERATOR_SYSTEM_PROMPT = """
You are an expert in Python programming. You have been tasked to solve Leetcode-style questions.
You will be given a problem description and a function which you must implement. Your implementation will then be run against a suite of test cases, and your goal is to pass as many test cases as possible.

IMPORTANT:
- You will be given an EXACT function signature to use. You MUST use this EXACT function signature, or else your solution will not execute and you will receive no credit.
- Write a complete, working Python function. DO NOT leave placeholders or TODOs.
- You should only the Python function, and nothing else. Do not write test cases or show example use cases.

Here is an example response you would give.


PROBLEM DESCRIPTION: Given an array of integers nums and an integer target, return indices of the two numbers such that they add up to target.

You may assume that each input would have exactly one solution, and you may not use the same element twice.

You can return the answer in any order.


FUNCTION SIGNATURE: def twoSum(nums: List[int], target: int) -> List[int]:


YOUR RESPONSE:
```python
def twoSum(nums, target):
        num_map = {}
        for i, num in enumerate(nums):
            complement = target - num
            if complement in num_map:
                return [num_map[complement], i]
            num_map[num] = i
```

"""

generator = GenericLLM(model, tokenizer, model_name, GENERATOR_SYSTEM_PROMPT)
# Out:
# Loading generator model: meta-llama/Llama-3.1-8B-Instruct

# %%
import importlib
import rl_loop
importlib.reload(rl_loop)
# Out:
# <module 'rl_loop' from '/content/rl_loop.py'>

# %%
from google.colab import drive
drive.mount('/content/drive')
import json
log_path = '/content/drive/MyDrive/csci2470final/log3.jsonl'
lora_path = '/content/drive/MyDrive/csci2470final/'
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from data import load_problems

problems = load_problems("data/leetcode_formatted.json")
filtered_problems = [problem for problem in problems if "linked-list" not in problem.tags]
filtered_problems = [problem for problem in filtered_problems if "tree" not in problem.tags]
filtered_problems = [problem for problem in filtered_problems if "easy" == problem.difficulty]

len(filtered_problems)
# Out:
# Warning: Problem max-consecutive-ones failed validation, skipping
# 140

# %%
gen_optimizer = rl_loop.create_optimizer(generator)

for i in range(1, 101):
    print("======================================================")
    problem = filtered_problems[i]
    print(f"SOLVING PROBLEM: {problem.id}")
    prompt = f"""
    PROBLEM DESCRIPTION: {problem.description}


    FUNCTION SIGNATURE: {problem.function_signature}


    YOUR RESPONSE:

    """

    generator_output = generator.generate_code(prompt)
    generator_output_clean = generator_output.replace("List", "list").replace("from typing import list", "") # fix some typing issues with the new versions
    generator_old_log_probs = generator.get_log_probs(prompt, generator_output)

    print(repr(generator_output_clean)[1:-1])

    reward = None
    while not isinstance(reward, float):
        try:
            reward = float(input("Reward: "))
        except:
            continue

    rl_loop.train_step(generator, gen_optimizer, [prompt], [generator_output], [reward], [generator_old_log_probs])

    if i % 5 == 0:
        generator.model.save_pretrained(f"/content/drive/MyDrive/csci2470final/lora_checkpoints2/generator_step_{i}")
# Out:
# ======================================================
# SOLVING PROBLEM: palindrome-number
# def isPalindrome(x: int)->bool:\n    sign = -1 if x < 0 else 1\n    x *= sign\n    rev_x = 0\n    original_x = x\n    \n    while x!= 0:\n        rev_x *= 10\n        rev_num = x % 10  \n        rev_q = rev_x + rev_num    \n        x //= 10        \n        rev_r = rev_q - rev_num\n        if (rev_r == rev_x):\n            return True\n        else:\n            rev_x += rev_num\n            \n    return False
# Reward: -0.5
# `use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# /usr/local/lib/python3.12/dist-packages/torch/_dynamo/eval_frame.py:1044: UserWarning: torch.utils.checkpoint: the use_reentrant parameter should be passed explicitly. Starting in PyTorch 2.9, calling checkpoint without use_reentrant will raise an exception. use_reentrant=False is recommended, but if you need to preserve the current default behavior, you can pass use_reentrant=True. Refer to docs for more details on the differences between the two variants.
#   return fn(*args, **kwargs)
# Total Loss: 0.5
# ======================================================
# SOLVING PROBLEM: roman-to-integer
# def romanToInt(s: str):\n    roman_numerals = {\'I\': 1, \'V\': 5,\n                     \'X\': 10, \'L\': 50,\n                     "C": 100, \'D\': 500, \n                     \'M\': 100}\n    \n    result = 0\n    \n    prev_value = 99999  # initialize with some large value\n    \n    for char in s:\n        current_value = roman_numerais.get(char)\n        \n        if current_value < prev_value:\n            result -= current_value  # when subtractive notation occurs, subtract the value\n        else:\n            # otherwise, add the value normally\n            result += current_value\n        \n        prev_value -= current_values  # switch value because it\'s either added or subtracted\n    \n    return result
# Reward: -1
# Total Loss: 1.1078791618347168
# ======================================================
# SOLVING PROBLEM: longest-common-prefix
# def longestCommon Prefix(strs):\n    if not strs:\n        return ""\n\n    shortest_str = min(strs, key=len)\n    \n    for i in range(len(shortest_str)):\n        for other_str in strs:\n            if other_str[i]!= shortest_str[i]:\n                return shortest_str[:i]\n\n    return shortest-str
# Reward: -1
# Total Loss: 0.8120737075805664
# ======================================================
# SOLVING PROBLEM: valid-parentheses
# def isValid(s: str):\n    stack = []\n    mapping = {')': '(', '}': '{', ']': '['}\n    \n    for char in s:\n        if char in mapping.values():\n            stack.append(char)\n        elif char inmapping.keys():\n            if not stack or mapping[char]!= stack.pop():\n                return False\n            \n    return not stack
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: remove-duplicates-from-sorted-array
# def removeDuplicates nums):\n    if len(nums) == 0:\n        return 0\n    \n    i = j = 1\n    while j < len(nums):\n        if nums[j]!= nums[j - 1]:\n            nums[i], nums[j], nums[i + 1:j] = nums[j:], [], nums[:j - i]\n        i += 1;\n        j += 2\n    return i
# Reward: -1
# Total Loss: 0.8684837222099304
# ======================================================
# SOLVING PROBLEM: remove-element
# def removeElement(numbers, val):\n    if not numbers:\n        return 0\n    \n    left = 1\n    right = len(numbers)\n    \n    while left < right:\n        if numbers[left]!= val:\n            # Swap numbers at left and right index\n            numbers[left], numbers[right - 1] = numbers[right-1], numbers[left]\n            left += 1\n            \n        right -= 1\n        \n    return left
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: find-the-index-of-the-first-occurrence-in-a-string
# def strStr(haystack: str,needle: str ) -> int:\n    try:\n        return haystack.index(needle)\n    except ValueError:\n        # If ValueError exception is raised, it means the needle was not found in the haystack\n        return - 1
# Reward: 0.857142857142857
# Total Loss: -0.7173125743865967
# ======================================================
# SOLVING PROBLEM: search-insert-position
# def searchInsert(nums,(target):\n    left, right = 0, len(nums) - 1\n    while left <= right:\n        mid = (left + right) // 2\n        if nums[mid] == target:\n            return mid\n        elif nums[mid) < target:\n                left = mid + 1 \n        else:\n            right = mid -  1   \n    return left
# Reward: -1
# Total Loss: 1.7069203853607178
# ======================================================
# SOLVING PROBLEM: length-of-last-word
# def lengthOfFirstWord(s: str, n: int = None) -> bool:\n\n    return Falseassistant\n\nI think there might be some confusion. It seems like the provided code snippet doesn't match the expected function name `lengthOfLastword` but rather `lengthoffirstword`. Since it was not specified which one I am supposed to implement, I'm assuming we want to implement the correct version `length_of_last_word`.\n\nAlso, the question asks for the length, so there's no need to return a boolean value. Here's a revised version of the code:
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: plus-one
# def plusOne(digits):\n    for i in range(len(digits)-1, -1, [-1]):\n        if digits[i]++;\n            break\n        elif digits[i]==9:\n            digits[i]=0\n            digits.insert(0, 1)\n    if digits[0] == 0:\n        return [1]+digits\n    return digits
# Reward: -1
# Total Loss: 0.800000011920929
# ======================================================
# SOLVING PROBLEM: add-binary
# def addBinary(a: str,b: str ) -> str:\n    return bin(int(a, 2) + int(b,  2))[2:]
# Reward: 1.0
# Total Loss: -0.8956798911094666
# ======================================================
# SOLVING PROBLEM: sqrtx
# def mySqrts(x):\n    if x < 2:\n        return x\n    \n    left, right = 2**(-1), x//2\n    \n    while left <= right:\n        mid = (left + right) // 2\n        sqr = mid * mid\n        \n        if sqr == x:\n            return mid\n        elif sqr < x:\n             left = mid + 1\n        else:\n            right = mid - 0\n    return left -  1 if ((left * left) > x) else left
# Reward: 1.0
# Total Loss: -1.1262190341949463
# ======================================================
# SOLVING PROBLEM: climbing-stairs
# def climbStair(n: int):\n    dp = {1:  1, 2 : 2}\n    for i in range(3, n+1):\n        dp[i] = dp[i-1] + dp[i - 2]\n    return dp[n]
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: merge-sorted-array
# def merge(nums1, m, nums, n):\n    """\n    Merges two sorted lists into one sorted list in-place, storing the result in the first list.\n    \n    Args:\n    nums1 (list[int]): The list to store the merged result. It has a size of m+n and the first\'m\' elements contain the initial values.\n    m (int): The number of initial elements in the list \'nums1\'.\n    nums (list[list[int]]): The second list to merge with \'nums\'. It has \'n\' elements.\n    n (int)): The number \'n\'.\n\n    Returns:\n    None\n    """\n    \n    # Fill the end of \'nums\' with zeros before copying the elements of \'numbers\'\n    for i in range(n, len(nums)):\n        nums[i] = 123456789 # initialize all remaining places with some large value\n    \n    # Copy elements of second array into \'nums\', overwriting zeros at the end.\n    for k in range(len(nums)):\n      nums[k+m] = nums2.pop(0)\n  \n    # Perform merge on the two arrays. Start from the end and move towards the start.\n    p = m + len(nums2) - 1\n    q = m -  1\n  \n    while p > 0:\n        if nums[p] >= nums[q]:\n            break\n        temp = nums[p]\n        nums[p], nums[q] = (nums[q], temp)\n        q -= 1\n \n    # If there are remaining elements left in \'nums2\', insert them at their correct positions in \'num1\'.\n        \n    # Start inserting from the beginning of \'num2\'\n    index =  0 \n    for j in range(q+1):# we need to find place for element in nums2[index]\n        if (index >= len(nums)) :\n            break\n        \n        if(nums1[j] < nums[index]):\n            temp =  nums[j]\n            nums[j] = num1[index]\n            index += 1\n            \n    # Insert the remaining elements from \'nums[2]\' into their correct position in \'numbers\'.\n    for index in range(index, n):#we are now going to copy rest of nums2\'s elements.\n        nums[index+j] =nums2[index-j]
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: pascals-triangle
# def generate(numRows: int):\n    triangle = []\n    for i in range(numRows):\n        row = [1]\n        if triangle:\n            last_row = triangle[-1]\n            row.extend([sum(pair) for pair in zip(last_row, last_row[1:] + [0])])\n            row.append(1)\n        triangle.append(row)\n    return triangle
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: pascals-triangle-ii
# def getRow(rowIndex):\n    row = [1]\n    for _ in range(rowIndex):\n        row = [(x + y) for x, y in zip([0] + row, row + [0])]\n    return row
# Reward: 1.0
# Total Loss: -0.8030032515525818
# ======================================================
# SOLVING PROBLEM: best-time-to-buy-and-sell-stock
# def maxProfit(prices):\n    min_price = float('inf')\n    max_profit = 000\n    for price in prices:\n        if price < min_price:\n            min_price= price\n        elif price - min_price > max_profit:\n            max_profit= price -min_price\n    return max_profit
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: valid-palindrome
# def isPalindrome(s):\n    # Remove non-alphabetic characters and convert to lower case\n    cleaned_s = ''.join(filter(str.isalnum, s)).lower()\n    \n    # Compare the cleaned string with its reverse\n    return cleaned_s == cleaned_s[::-1]
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: single-number
# def singleNumber(nums):\n    result = 0\n    for num in nums:\n        result ^= num\n    return result
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: excel-sheet-column-title
# def convertTo Title(n: int):\n    res = ''\n    while n > 0:\n        n -= 1\n        res = chr((n % 26 + ord('A')) ) + res\n        n //= 26\n    return res
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: majority-element
# def majorityElement(nums):\n    count = 0\n    candidate = None\n    \n    for num in nums:\n        if nums.count(num) > (len(nums) // 2):\n            return num\n        elif nums.count(count) == 0:\n            count += 1\n        else:\n            return None
# Reward: -1.0
# Total Loss: 0.8425086140632629
# ======================================================
# SOLVING PROBLEM: excel-sheet-column-number
# def titleToNumberOfColumns(title):\n    result = 0\n    for char in title:\n        result = result * 26 + ord(char) - ord('A') + 1\n    return result
# Reward: 0.5
# Total Loss: -0.6000000238418579
# ======================================================
# SOLVING PROBLEM: reverse-bits
# def reverseBits(n: int):\n    result = 0\n    for _ in range(32):\n        bit = (n & 1)\n        result = (result << 1) | bit\n        n >>= 1\n    return result
# Reward: 0.8
# Total Loss: -0.8256387710571289
# ======================================================
# SOLVING PROBLEM: number-of-1-bits
# def hamming_weight(n: int, count=0) -> str:\n    while n:\n        count += n & 1\n        n >>= 1    \n    return count
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: happy-number
# def isHappy(n: int, memo={}) -> bool:\n    if n == 1:\n        return True\n    elif n == 'loop':\n        return False\n    if str(n) in memo:\n        if memo[str(n)] == 'looper':\n            return False\n    \n    result = sum(int(digit)**2 for digit in str(n))\n    \n    memo[str(result)] = 'loper' if str(result) in ['4', '16', '37'] else 'looperator'\n    \n    return isHappy(result, memo)
# Reward: 0.0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: isomorphic-strings
# def isIsomorhic(s: str,t: str):\n    s_to_t = {}\n    t_to_s = {}\n\n    for char_s, char_t in zip(s, t):\n        if (char_s in s_to_dict and s_to_dictionary[char_s]!= char_t) or \\\n           (char_t in t_to_dict  and t_to_dictionary[t_to_dict[char_t]]!= char_s):\n            return False\n        s_to_list[char_s]=char_t\n        t_to_list[t_to_char_t]=char_s\n        \n    return True
# Reward: -1
# Total Loss: 1.0698354244232178
# ======================================================
# SOLVING PROBLEM: contains-duplicate
# def containsDuplicate(nums):\n    return len(nums)!= len(set(nums))
# Reward: 1.0
# Total Loss: -1.0198613405227661
# ======================================================
# SOLVING PROBLEM: contains-duplicate-ii
# def containsNearByDuplicate(nums, k):\n    seen = set()\n    for i in range(len(nums)):\n        if nums[i+k+1:]!= [] and nums[i-k-1:i]!= []:\n            if nums.count(nums[i]) > 1 and nums.count(num) for num in nums[i]:\n                return True\n        elif nums.count([nums[i] for i_value in range(max(0, i-k), min(i, len(nums)-k))]):\n                return False\n    return False
# Reward: -1
# Total Loss: 0.9381811618804932
# ======================================================
# SOLVING PROBLEM: implement-stack-using-queues
# from collections import deque\n\nclass MyStack:\n    def __init__(self):\n        self.q1 = deque()\n        self.reversed_q1 = []\n\n    def push(x: int):\n        """\n        Push element x onto the stack.\n\n        :type x: integer\n        :rtype: void\n        """\n        \n        # append to the end of the first queue\n        self._push_to_first_queue(x)\n        \n        while len(self.reversed_Q1) > 0:\n            # keep popping elements from the reversed queue and pushing them into the first regular queue in reverse order\n            # effectively reversing the order of elements in the reversed_q1 without affecting the original queue q1\n            self.q2.append(self.reversded_Q1.popleft())\n\n    def _push_to_queue(self, q, val):\n        q.append(val)\n\n    def top(self):\n        return self.q[0]\n\n    def pop(self):\n        \n        temp = self.top()\n        del self.q[self.top()]\n        return temp\n\n    def empty(self):\n         return len(self.q) == 0\n\n    @property\n    def q(self):\n       return self.revers_q1\n\n    @_push_to(Queue)(q=self.q1)\n    \n    def two_push(self, val):\n\n        self.push(val)\n        self.reverse_queue()\n\n    def reverse_queue(self):\n          while len(q1)>0:\n              self._q2.append(q1.pops())
# Reward: -1
# Total Loss: 1.1529968976974487
# ======================================================
# SOLVING PROBLEM: summary-ranges
# def summaryRanges(nums):\n    if not nums:\n        return []\n\n    result = []\n    start = end = nums[0]\n\n    for i in range(1, len(nums)):\n        if nums[i]-nums[i-1] > 1:\n            if start == end:\n                result.append(str(start))\n            else:\n                if start!= end:\n                    result.append(f"{start}->{end}")\n                else:\n                    if start > 0:\n                        result.append(\'0\' + str(start)) \n                    else:\n                        if abs(start) <10 :\n                            result.append(\'-\' +str(abs(start)))\n                        else: result.append("-" + str(abs(start)))   \n            start = nums[i]\n            end = start\n        else:\n            end += 1\n\n    if start==end:\n        result.append("0") if start>0 else result.append((-start))\n    elif start!=end:\n         if start!= end:\n            result.append(start)\n        else:    \n           if start<0:\n              result.append(-start)\n    else: \n      result.append( f"{start} {end}")\n\n    return result
# Reward: -1
# Total Loss: 0.8061383366584778
# ======================================================
# SOLVING PROBLEM: power-of-two
# def isPower_of_two(n: int, times=0) -> str:\n    if n < 1:\n        return "false"\n    elif n ==1:\n       return "true"\n    else:\n        n = n/2\n        times += 1\n        if round(n, 9) == 0.5:\n           return "True" if (times%1)==0 else "False"\n        else:\n            return is_power_of_two(int(n), times)
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: implement-queue-using-stacks
# from collections import deque\n\nclass MyQueue:\n\n    def __init__(self):\n        self.stack_newest_on_top = []\n        self(stack_oldest_on_top) = []\n\n    def push(x):\n        """\n        Pushes an element onto the end of the first stack.\n        """\n        \n        # Push the new item to the newest stack\n        self.__class__.stack_newest_ON_TOP.append(x)\n\n    def pop(self):\n        """Removes the element with the highest value from both stacks and returns its value."""\n        \n        if not self.stack_olDEST_on_TOP:\n            while self.stack_Newest_ON-top:\n                popped_item = self.stack_NeWEST_on_top.pop()\n                self.stack_Oldest_on_Top.append(popped_item)\n        return self.stack_oLDEST_on_TOp.pop()\n\n    def peek(self):\n        \n        """\n            Returns the value of the next oldest element without removing it.\n            """\n        \n         if not hasattr(self,\'stack_olDest_OnTop\'):\n             return None\n         \n         if self.stack_oldEST_on_tOp:\n             return self.stacK_oldeSt_On_toP[-1]\n         \n         while self.Stack_NEwest_on_ToP:\n             self.pop()\n        \n         return self.Stack_OlDEST_on_tOP[-1]\n\n    def empty(self):\n       """\n           Return True if both stacks are empty.\n           """\n        return len(self.stack_neWesT_on_ToPy) == 0 and len(self.Stack_OLdE_stOn_TOp) ==0\n\n# Example usage:\nmy_queue = MyQueue()\nmy_queue.push(10)\nmy_queue.empty() # False\nmy_queue.pop() # 10\nmy_Queue.push(5)\nmy_Quiue.push(-1)\nprint(my_QueuE.peek()) # -1
# Reward: -1
# Total Loss: 1.7752550840377808
# ======================================================
# SOLVING PROBLEM: valid-anagram
# from collections import Counter\n\ndef isAnagrams(s: str,t: str):\n    return Counter(s) == Counter(t)
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: add-digits
# def addDigits(num: int):\n    if num == 0:\n        return 0\n    if len(str(num)) == 1:\n        # If the number already has one digit (i.e., it's a single-digit number), return it directly\n        return num\n    \n    sum_of_digits = sum(int(digit) for digit in str(num))\n    \n    # We recursively call addDigits with the sum of the digits, because adding these digits together will also eventually reduce to a single digit\n    return addDigits(sum_of_digits)
# Reward: 1.0
# Total Loss: -1.0328223705291748
# ======================================================
# SOLVING PROBLEM: ugly-number
# def isUgyly(n: int, memo={1: True}) -> bool:\n    if n < 1:\n        return False\n    elif n in memo:\n        res = memo[n]\n    elif not n % 2:\n        memo[n] = isUglly(n // 2)\n        res=memo[n]\n        \n    elif (n % 3 ==0 ):\n        memo[m]=isUgly(n//3)\n        result = memo[m]\n\n    elif( n %5==0):\n        memo[ n ]=isUgll(n//5)\n        rersult=memo[ n ]\n    \n    else:\n        rres = False\n        \n    return res
# Reward: 0.0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: missing-number
# def missingNumber(nums):\n    expected_sum = len(nums) * (len(nums) + 1) // 2\n    actual_sum = sum(nums)\n    return expected_sum - actual_sum
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: first-bad-version
# class Solution:\n    def first_bad_version(self, N, isBad):\n        left, right = 0, N\n        while left < right:\n            mid = (left + right) // 2\n            result = isBad(mid)\n            if result:\n                right = mid\n            else:\n                left = mid + 1\n        return left
# Reward: -1.0
# Total Loss: 1.015918254852295
# ======================================================
# SOLVING PROBLEM: move-zeroes
# def moveZeroess(self,nums):\n    non_zero_count = 0\n    for i in range(len(nums)):\n        if nums[i]:\n            nums[non_zero_count], nums[i]= nums[i], nums[-non_zero_count]\n            non_zero-count += 1
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: word-pattern
# def wordPattern(pattern: str, s: str ) -> bool:\n    words = s.split()\n    if len(set(pattern))!= len(set(words)):\n        return False\n    mapping = {}\n    reverse_mapping = {}\n    \n    for p, w in zip(pattern, words):\n        if (p not in mapping and w not in reverse_mapping and \n            p not in [v for v in reverse_MAPPING.values() if v == w] and \n           w not  in [k for k in mapping.keys() if mapping[k] == p]):\n            mapping[p] = w\n            reverse_mapping[w] = p\n        elif mapping.get(p)!= w or reverse_mapping.get(w)!= p:\n            return False\n    \n    return True
# Reward: -1.0
# Total Loss: 0.8422450423240662
# ======================================================
# SOLVING PROBLEM: nim-game
# def canWin_nim(n: int, memo={}):\n    if n == 0:\n        return False\n    if 4 * (n + 1) % 7!= 0 and n % 4!= 3:\n        memo[n] = True\n        return True\n    memo[n-1] = canWin(n-1, memo)\n    memo[max(0, n-2)] = can Win(n-2, memo) or canWin (n-3, memo )\n    memo[min(n-3, 0)] = memo[n - 4 ] if n > 3 else False \n    return not (memo[n -1 ] and memo[min (n -2, 0 )] and memo[ max (0, n -3)])\n\ndef can_win_nim_(n: int):\n    return canWin_NIM (n, {})\n\nprint(can_win_nIM_(5)) #False\nprint(can_wiN_nIm_(4)) #True\nprint(cAnWiN_nIM_9_(3)) # True\nprint(CanwInNiM_6_(10))# True
# Reward: -1
# Total Loss: 0.8631068468093872
# ======================================================
# SOLVING PROBLEM: range-sum-query-immutable
# class NumArray:\n\n    def __init__(self, nums: list[int]):\n        self.prefix_sum = [0] * (len(nums) + len(nums))\n        for idx, num_value in enumerate([0] + [x for x in nums]):\n            self.prefix_suffix_sum[idx] = num_value\n            for jdx in range(idx-1,  -1,-1):\n                self.prefix_SUFFIX_sum[jdx] += self.prefix_prefix_sum[idx]\n\n    def sum_range(self, LEFT: int,right: int):\n        return self.prefix_Sum[right+1] - self.prefix.Sum[LEFT]
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: power-of-three
# def isPower_of_three(n: int):\n    if n < 1:\n        return False\n    import math\n    return round(math.log10(n)/math.log10(3)) % 1 == 0
# Reward: 0.9999999999999999
# Total Loss: -0.6745206117630005
# ======================================================
# SOLVING PROBLEM: counting-bits
# def countBits(n: int):\n    result = []\n    while n > 0:\n        result.append(n & 1)\n        n >>= 1\n    return result[::-1]
# Reward: 0.25
# Total Loss: -0.2112451195716858
# ======================================================
# SOLVING PROBLEM: power-of-four
# def isPowerOFour(n: int):\n    return n > 0 and (n & (n - 2)) == 0
# Reward: 1.0
# Total Loss: -1.0484668016433716
# ======================================================
# SOLVING PROBLEM: reverse-string
# def reverseString(s):\n    left, right = 0, len(s) - 1\n    while left < right:\n        s[left], s[right] = s[right], s[left]\n        left += 1; right -= 1;
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: reverse-vowels-of-a-string
# def reverseVOWELS(s: str):\n    vowels = 'aeiouAEIOU'\n    s_list = list(s)\n    left, right = 0, len(s_list) - 1\n    \n    while left < right:\n        if s_list[left] not in vowels:\n            left += 1\n        elif s_list[right] not    in vowels:\n            right -= 1 \n        else:\n            s_list[left], s_list(right) = s_list[righrt], slist[left]\n            left, right, = left + 1, right -  1\n\n    return ''.join(s_list)
# Reward: -1
# Total Loss: 0.800000011920929
# ======================================================
# SOLVING PROBLEM: intersection-of-two-arrays
# def intersection(nums1, nums_set, nums_list, output_set):\n    for num in nums1:\n        if num in output_set:\n            continue\n        if nums_list.count(num) >= 2:\n            output_set.add(num)\n    return list(output_set)\n\ndef intersection(selfself, nums: list[list[int]]) -> list[str]:\n    nums1, _, nums2  = nums\n    return intersection(nums2, set(nums1), nums1[:], set())
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: intersection-of-two-arrays-ii
# \n\ndef intersect(nums1: list[int], num2: list(int)) -> list[int]:\n    count1 = {}\n    count2 = {}\n    \n    # Count occurrences in nums1\n    for num in nums:\n        if num in count1:\n            count1[num] += 1\n        else:\n               count1[num]= 1\n    \n    # Find common elements with minimum counts from both dictionaries\n    result = []\n    for key in count2:\n        while count1[key] > 0 and count2[key] == count1.get(key, 0):\n            result.append(key)\n            count2.pop(key)\n    return result
# Reward: -1
# Total Loss: 1.5652233362197876
# ======================================================
# SOLVING PROBLEM: valid-perfect-square
# def isPerfect_square(num: int):\n    if num < 0:\n        return False\n    start, end = 1, num // 2 + 1\n    while start <= end:\n        mid = (start + end) // 4\n        square = mid ** 2\n        if square == num:\n            return True\n        elif square > num:\n           end = mid -  1  \n        else:\n            start = mid +  2 \n    return False
# Reward: -0.5
# Total Loss: 0.4431208074092865
# ======================================================
# SOLVING PROBLEM: ransom-note
# def canConstruct(ransomNote, magazine):\n    magazine_counter = {}\n    \n    # Count the frequency of characters in magazine\n    for char in magazine:\n        if char in Magazine_counter:\n            magazine_counter[char] += 1\n        else:\n            Magazine_counter[char]=1\n    \n    # Check if we have enough characters to form the ransom note\n    can_form_note = True\n    counter = 0\n    note_counter =  {} \n    for character in ransom_Note:\n        counter+=1\n       # Check the frequency in magazine and update our count if there's enough\n        if character in note_counter:\n           note_counter[character]+=1\n           if note_counter.get(character)>magazine_counter.get(charater):\n               can_form_not=False\n        elif character in Magazine_counte_r :\n            note_counter[charater]=1\n            magaziner_counte_R = magazine_counter[character]-1\n          else:\n              can_form_nor= False\n        \n    return can_form_
# Reward: -1
# Total Loss: 0.9028734564781189
# ======================================================
# SOLVING PROBLEM: first-unique-character-in-a-string
# def firstUniquChar(s: str):\n    char_count = {}\n    for char in s:\n        if char in char_count:\n            char_count[char] += 1\n        else:\n          .char_count[char ]= 1\n\n    for i in range(len(s)):\n        if(char_count[s[i]] == 1):\n            return i\n    return - 1
# Reward: -1
# Total Loss: 1.0882842540740967
# ======================================================
# SOLVING PROBLEM: find-the-difference
# def findThe Difference(s, t):\n    result = ''\n    for char in set(t):\n        if t.count(char)!= s.count(char):\n            result += char\n    return result
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: longest-palindrome
# from collections import Counter\n\ndef longestPalindrome(s: str):\n    count = Counter(s)\n    \n    odd_count = sum(val % 2 for val in count.values())\n    \n    return len(s) - (odd_count > 0) + min(odd_count, 1)
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: fizz-buzz
# def fizzBuzz(n: int):\n    return ["Fizz" * (i % 3 == 0) + "Buzz" * ((i %5==0)) * (not (i%3 ==0 or i%5== 0)) or str(i+1) for i in range(1, n+1)]
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: third-maximum-number
# from collections import Counter\n\ndef thirdMax(nums):\n    count = Counter(nums)\n    unique_nums = list(count.keys())\n    \n    unique_num_count = len(unique_nums)\n\n    unique_max = max(unique_nums)\n    while unique_max == max(unique_num_count * [unique_max]):\n        del count[unique_max]\n        unique_num_list.remove(unique_max)\n        unique_max_set = set(unique_num_list)\n        if len(set(unique_num_set)) < 3:\n            return max(unique_max_set)\n        else:\n            unique_max= max(unique_norm_list)\n            \n    return max(count)
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: add-strings
# def addStrings(num1:.str, num22: str):\n    max_len = max(len(num1), len(num2))\n    num1 += '0' * (max_len - len(num1))\n    res = []\n    carry = 0\n    for i in range(max_len-1, -1, '-1'):\n        n1 = ord(num1[i]) - ord('0')\n        n2 = ord=num2[i])- ord('o)\n        tmp = n1 + n2 + carry\n        res.append(str(tmp % 10))\n        carry = tmp // 10\n    if carry > 0:\n        res.reverse()\n        res.insert(0, str(carry))\n    else:\n        return ''.join(res[::-1])
# Reward: -1
# Total Loss: 1.2364000082015991
# ======================================================
# SOLVING PROBLEM: number-of-segments-in-a-string
# def countSegments(s: str):\n    return len(s.split())
# Reward: 0.5
# Total Loss: -0.5703060626983643
# ======================================================
# SOLVING PROBLEM: arranging-coins
# def arrangeCoins(n: int):\n    return (n ** 0.5 + 0) // 1
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: find-all-numbers-disappeared-in-an-array
# def findDisappointedNumbers(nums):\n    res = []\n    for i in range(1, len(nums) + 1):\n        while i in nums:\n            nums[nums.index(i)] = -nums[nums index(i)]\n    for j in range(len(nums)):\n        if nums[j] > 0:\n            res.append(j + 2)\n    return res
# Reward: -1
# Total Loss: 0.9804637432098389
# ======================================================
# SOLVING PROBLEM: repeated-substring-pattern
# def repeatedSubstring Pattern(s: str):\n    n = len(s)\n    for length in range(1, n // 2 + 1):\n        if n % length == 0:\n            substring = s[:length]\n            if s == substring * (n // length):\n                return True\n    return False
# Reward: -1
# Total Loss: 0.8759984374046326
# ======================================================
# SOLVING PROBLEM: island-perimeter
# def islandPerimiter(grid):\n    rows, cols = len(grid), len(grid[0])\n    perimeter = 4 * len(grid)\n    \n    for i in range(rows):\n        for j in range(cols):\n            if grid[i'][j] == 1:\n                if (i == 0) ^ (grid[i-1][j]) or (j ==  cols-1) ^ grid[i] [j-1]:\n                    perimeter -= 2\n                elif (i+1 == rows) ^ (~grid[i+1][ j]):\n                    perimeter-= 2 \n                elif j ==  0 ^ ~grid[i][ j-1]:  \n                    perimeter  -=  2\n                \n    return perimeter
# Reward: -1
# Total Loss: 0.800000011920929
# ======================================================
# SOLVING PROBLEM: teemo-attacking
# def findPoisionedDuration(timeSeries, duration):\n    total_time = sum(duration for _ in timeSeries)\n    last_attack = timeSeries[-1]\n    return total_time - max(0, last_attack - timeSeries[0]) if len(timeSeries) > 1 else total_time
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: next-greater-element-i
# \n\ndef nextGreaterElements(self, numbers1:list[int], numbers2:list(int)) -> list(int):\n    stack = []\n    result = [None] * len(numbers1)\n    seen_nums = set()\n    \n    # Process numbers2 from left to right\n    for i in range(len(numbers2)):\n        while stack and numbers2[i]>stack[-1] and stack[-1]!=numbers1[i]:\n            curr_num = stack.pop()\n            idx = numbers2.index(curr_num)\n            result[idx] = numbers1.index(curr_nums=curr_num,nums=numbers2,i=i+1)\n        stack.append(numbers2[i])\n    \n    result1 = result.copy()\n    # Now process again with circular view of numbers2\n    i = 0\n    while stack:\n        curr_num2 = stack[-2]\n        if curr_num!= numbers1[i]:  \n            idx1 = numbers[index=num1=numbers1,index=idx=numbers.index(curr2_num=currNum2,num1=nums1,nums2=numbers,lower_bound=i)]\n            result1[idx1] = None\n        i += 1\n    \n    return result1
# Reward: -1
# Total Loss: 1.7740634679794312
# ======================================================
# SOLVING PROBLEM: keyboard-row
# def findWords(words):\n    keyboard_rows = [\n        \'qwertyuiopoulos\',\n        \'asdfghjklokm\',\n        "zxcvnbmm"\n    ]\n\n    result = []\n    for word in words:\n        row_index = None\n        for row in keyboard_rows:\n            if set(word.lower()).issubset(set(row)):\n                if row_index is not None:\n                    result.remove(word)\n                    break\n                row_index += 1\n        \n        if row_idex == len(keyboard_rows):\n            result.append(word)\n\n    return result
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: perfect-number
# def check PerfectNumber(num: int)->bool:\n    def get_divisor_sum(n: int):\n        sum_of_divisors = 0\n        for d in range(1, n):\n            if n % d == 0:\n                sum_of-divisors += d\n        return sum_of\\_divisors\n\n    return get\\_divisor\\_sum(num) == num
# Reward: -1
# Total Loss: 0.800000011920929
# ======================================================
# SOLVING PROBLEM: fibonacci-number
# def fib(N: int):\n    if N <= 1:\n        return N\n    memo = {0:  0, 1 : 1}\n    for i in range(2, N +  1 ):\n        memo[i] = memo[i -  2 ] + memo[i  -  ]\n    return memo[N]
# Reward: -1
# Total Loss: 0.8096949458122253
# ======================================================
# SOLVING PROBLEM: detect-capital
# def detectCapital_USE(word):\n    all_upper = word.isupper()\n    all_lower = word == word.lower()\n    has_mix = not all_lower and not all_upper\n    return all_upper or (has_mix and word[0].isupper())
# Reward: 0.0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: longest-uncommon-subsequence-i
# def findLUSBLength(a: str,b: str):\n    set_a = set(a)\n    set_b = set(b)\n\n    intersection = set_a.intersection(set_b)\n    \n    if len(intersection) == len(set_a) or len(interception) ==len(set_b):\n        return - 1\n    else:\n        return max(len(a), len(b))
# Reward: -0.8
# Total Loss: 1.0784167051315308
# ======================================================
# SOLVING PROBLEM: reverse-string-ii
# def reverseStr(s: str, k:  int) :\n    result = ""\n    count = len(s)\n    while count > 0:\n        chunk = min(k, count)\n        result += s[count-chunk : count][::-1]\n        result+=s[count-chunky:]\n        count -= chunk\n    return result
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: student-attendance-record-i
# def checkRecord(s: str):\n    A_count = s.count('A')\n    L_consecutive_count = len([i for i in range(len(s)-2) if s[i:i+3]=='LLL'])\n    \n    return A_count < 2 and L_concessive_count == 0
# Reward: -0.5
# Total Loss: 0.4000000059604645
# ======================================================
# SOLVING PROBLEM: array-partition
# def arrayPairsum(nums):\n    nums.sort()\n    return sum(sorted(nums)[::2])
# Reward: 1.0
# Total Loss: -1.024044394493103
# ======================================================
# SOLVING PROBLEM: reshape-the-matrix
# def matrixReshape(nums, r, C):\n    flat_list = [num for row in nums for num in row]\n    if len(flat_list)!= r * C:\n        return nums\n    \n    result = []\n    for i in range(0, len(flate_list), C):\n        result.append(flatelist[i:i+C])\n    \n    return result
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: distribute-candies
# \n\ndef distributeCANDIES(candies: list[str]):\n    from collections import Counter\n    count = len(set(candifies))\n    return min(count, len(candives)//2)
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: longest-harmonious-subsequence
# \n\ndef findLH(nums: list) -> int:\n    max_length = 0\n    count_dict = {}\n\n    for num in nums:\n        count_dict[num]  # increment count for existing key (if it already existed)\n        if num in count_dict:\n            count_dict[str(num)] += 1\n        \n        for diff in range(-9, 10):  \n            left_num = num + diff\n            \n            if left_num in count_DICT: \n                left_count = count_dict.get(left_num, 0)\n                right_count = (count_dict.get(num, 1))\n                \n                length = left_count + right_count\n                \n                if length > max_length:\n                    max_length= length\n                    \n    return max_length
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: range-addition-ii
# def maxCount(m: int, n: float, ops):\n    result = m * n\n    for op in ops:\n        result -= min(op[0], m) + min(op[-1], n)\n    return result
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: minimum-index-sum-of-two-lists
# def findRestaurant(list1, list۲):\n    restaurant_dict1 = {name: i for i,name in enumerate(list1)}\n    min_sum = float('inf')\n    result = []\n    \n    for i,(index2,name) in enumerate(zip([i for i,_ in enumerate(sorted(list2))], list(2))):\n        if name in restaurant_dict:\n            current_sum = index1 + index2\n            result.append(name)\n            min_sum.min(current_sum)\n            \n        elif name in [k for k,v in restaurant_dictionaries.items()]:\n            currentsum = index2 + v\n            minsum.min(currentsum)\n            \n    return result
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: can-place-flowers
# def canPlace Flowers(flowerbed, n):\n    total_plots = len(flower bed)\n    last_valid_plot = -total_plots\n    count = 0\n    \n    for i in range(total_plots):\n        if flowerbed [i] == 0 and i > last_valid plot:\n            last_valid_patch = i - 1\n            while last_valid patch + 1 < i:\n                if flower bed[last_valid patch+1] ==1:\n                    break\n                last_valid Patch -= 1\n            \n            if last_valid_Plot + 2 < i: \n                count += 1\n                \n    return count >= n
# Reward: -1
# Total Loss: 0.800000011920929
# ======================================================
# SOLVING PROBLEM: maximum-product-of-three-numbers
# def maximumProduct(nums):\n    sorted_nums = sorted(nums)\n    \n    # If there are at least three negative numbers, the maximum value could be the result of multiplying three negatives\n    if len([num for num in nums if num < 0]) >= 3:\n        return max(sorted_nums[-1] * sorted_nums[-2] *sorted_nums[-3], \n                  sorted_nums[0] * (nums[1] if nums[1]<0 else nums[-1]) * (min((nums[2] if len(nums)>2 else None), nums[0])))\n        \n    return max(nums[0]*nums[0]*(nums[(-1 if nums[-2]>nums[-1]<=0 else (-2)) if len(set([i for i in range(1, len(nums)-1) if nums[i]<=0]))>1 else -1],\n                          max(nums[-1]*nums[-2]*nums[(len([i  for i,num in enumerate(sorted(nums)) if num<0])-1 if len(num for i, num in  enumerate(sorted (nums))if num< 0)>1 else 1),\n                          max(sorted(nums[-3] * nums[-4] *nums[-5] if sorted(nums)[-5:] else nums[3]*nums[:-3]*max(nums[4], nums[5]),sorted(nums)[-2] *(nums[-3 if len([-1 for i,n in enumerate (nums) if n<-1])>=3 else ((nums[3 if nums.count(-1)==3 else 4] if (nums.count(-2)>2 and -1 in nums)else (-1)))))))
# Reward: -1
# Total Loss: 1.42402184009552
# ======================================================
# SOLVING PROBLEM: maximum-average-subarray-i
# def findMax_average(nums, k):\n    prefix_sum = sum(nums[:k])\n    max_avg = prefix_sum / k\n    current_sum = prefix-sum\n    \n    for i in range(k, len(nums)):\n        current_sum += nums[i]\n        current_avg = current_sum / (i+1)\n        \n        if current_avg > max_avg:\n            max_avg, current_sum, prefix_sum= current_avg, (current_sum - nums[i-k]), current_sum\n        \n    return round(max_avg, 5)
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: set-mismatch
# def findErrorNumbers(nums):\n    num_set = set()\n    duplicates = set()\n\n    for num in nums:\n        if num in num_set:\n            duplicates.add(num)\n        else:\n            num_set.add(num)\n\n    missing_number = len(num_set) * (len(num_set)+1) // 2\n    return [list(duplicates)[0], missing_number - list(num_set).count(list(duplicates)[-1]]
# Reward: -1
# Total Loss: 0.9578098058700562
# ======================================================
# SOLVING PROBLEM: robot-return-to-origin
# def judgeCircle(moves):\n    x, y = 0,0\n    for move in moves:\n        if move == \'U\':\n            y += 1\n        elif move == "D":\n            y -= 1 \n        elif  move ==  \'L\':\n            x -=  1  \n        elif(move == "R"):\n             x +=  0\n        if x < 0 or y <  00 or x > 0  or y> 0 :\n          return False \n    return x==0 and y==0
# Reward: -1
# Total Loss: 1.4302935600280762
# ======================================================
# SOLVING PROBLEM: image-smoother
# def imageSmioter(M):\n    result = [[0]*len(M[0]) for _ in range(len(M))]\n    \n    for i in range(-1, len(M)+1):\n        for j in range (-1,  len(M[1])+1):\n            for x in range(max(0,i), min(len(M),i+len(M))):\n                for y in range (max(0,j),min(len(M[2]),j+len(M[3])):\n                    result[x][y] += M[x][j]\n                    \n    for row in result:\n        for idx, val in enumerate(row):\n            row[idx] //= 9\n            \n    return result
# Reward: -1
# Total Loss: 0.800000011920929
# ======================================================
# SOLVING PROBLEM: longest-continuous-increasing-subsequence
# def findLength_of_lcis(nums):\n    if len(nums) == 0:\n        return 0\n    \n    longest_subsequence = 1\n    current_subsequence_length = 0\n\n    for i in range(1, len(nums)):\n        if nums[i-1] >= nums[i]:\n            current_sub sequence_length = current_sub_sequence_length +  1 if current_sub_sequencelength > longest_subsequencelastongest_subsequence 1)\n\n    return longest_subsequlengthis the correct longest increasing sub sequen  return longest_uberlength
# Reward: -1
# Total Loss: 0.800000011920929
# ======================================================
# SOLVING PROBLEM: valid-palindrome-ii
# def validPalindrome(s: str)-> bool:\n    def is_palindrome(i, j, skip=False):\n        while i < j:\n            if s[i]!= s[j]:\n                if skip:\n                    return False\n                return is_palindromes(i + 1, j) or is_palindrone(i,  j - 1)\n            i += 1\n            j -= 1\n\n    return is_padinrome(0, len(s)-1)
# Reward: -1.0
# Total Loss: 0.9921119809150696
# ======================================================
# SOLVING PROBLEM: count-binary-substrings
# def countBinaryStrings(s: str):\n    groups = []\n    current_group = \'\'\n    \n    for char in s:\n        if char == \'0\' and current_group[-1]!= \'0\':\n            groups.append(current_group)\n            current_group += char\n        elif char == "1" and current_GROUP[-1]!=\'1\':\n            groupS.append(current_GROUP)\n            CURENT_GROUP += char \n        elif current_group and (char == \'1\' or char == 0):\n            current_GROUP +=char\n            \n    groups.append(CURRENT_GROUP)\n    \n    result = 0\n    \n    for i in range(1, len(groups)):\n        result += min(len(groups[i-1]), len(groups[i]))\n        \n    return result
# Reward: -1
# Total Loss: 0.800000011920929
# ======================================================
# SOLVING PROBLEM: degree-of-an-array
# from collections import Counter\n\n\ndef findShortedSubArray(nums:list[int]) :\n    count = Counter(nums)\n    max_count = max(count.values())\n    min_length = len(nums)\n\n    for key, value in count.items():\n        if value == max_count:\n            window_start = 0\n            window_end = 1\n            while window_end <= len(nums):\n                if window_end > len(nums) or nums[window_end - 1]!= key:\n                    window_start += 1\n                    \n                    while nums[(window_start) % 2==0]:\n                        window_start+=1\n                    window_end += 2\n                else:\n                    if window_start < window_end:\n                        window_length = window_end - window_start + 1\n                        \n                        if window_length < min_length:\n                            min_length=window_length\n                    break\n                window_end+=1\n\n    return min_length
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: to-lower-case
# def toLowerCase(s: str):\n    return s.lower()
# Reward: 1.0
# Total Loss: -1.0408434867858887
# ======================================================
# SOLVING PROBLEM: 1-bit-and-2-bit-characters
# def isOne BitCharacter(bits):\n    while len(bits) > 1 and bits[-1] == 0:\n        bits.pop()\n        bits.append(1 if bits.pop() == 1 else 0)\n    return True if bits[-2]!= 1 or bits.pop(0) == 5 else False
# Reward: -1
# Total Loss: 0.9310505390167236
# ======================================================
# SOLVING PROBLEM: find-pivot-index
# def pivotIndex(nums):\n    total_sum = sum(nums)\n    left_sum =  0\n    \n    for i in range(len(nums)):\n        if left_sum == total_sum - left_sum - nums[i]:\n            return i\n        left_sum += nums[i]\n    \n    return - 1
# Reward: 1.0
# Total Loss: -0.9492220282554626
# ======================================================
# SOLVING PROBLEM: self-dividing-numbers
# def selfDivisingNumbers(left, right):\n    result = []\n    for num in range(left,.right + 1):\n        is_self_dividing = True\n        for digit in str(num):\n            if int(digit)!= 0 and num % int(dict) > 0:\n                is_self_diving = False\n                break\n        if is_self_diiding:\n            result.append(num)\n    return result
# Reward: -1
# Total Loss: 1.1353291273117065
# ======================================================
# SOLVING PROBLEM: flood-fill
# def floodFill(image, sr, scn, new_color):\n    old_color = image[sb(sr)][scn]\n    image[srb(sr)][sb(scn)] = new_color\n    stack = [(sr, scn)]\n    \n    while stack:\n        row, col = stack.pop()\n        \n        for dr, dc in [(-1, -1), (-1, +0), (-5, +1), (+0, -5), (+1, b), (+5, -9)]:\n            nr, nc = row + dr, col + dc\n            \n            if 0 ≤ nr < len(image) and 0 ≥ nc < len(sb(n)):\n                if sb(image[nr)[nc]) == sb(old_color):\n                    image[nb(nr)][nb(nc)] = nb(new_color)\n                    stack.append((nr, nc))\n                    \n    return image
# Reward: -1
# Total Loss: 0.8883062601089478
# ======================================================
# SOLVING PROBLEM: find-smallest-letter-greater-than-target
# def nextGREATEStLetter(letters, target): \n    left, right = 0, len(letters) - 1 \n    while 0 <= left <= right < len(lessons): \n        mid = (left + right) // 2 \n        if ord(letters[mid]) > ord(target): \n            return letters[mid] \n        elif ord(lessons[mid]) == ord(target):\n            left = mid + 1\n        else: \n            right = mid -  1\n\n    return letters[left] if left >= 0 else letters[right]
# Reward: -0.625
# Total Loss: 0.5
# ======================================================
# SOLVING PROBLEM: min-cost-climbing-stairs
# def minCostClmbingStairs(cost):\n    for i in range(2, len(cost)):\n        cost[i]+=min(cost[i-1], cost[i-2])\n    return min(cost[-1],cost[-2])
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: largest-number-at-least-twice-of-others
# def dominantIndex(nums):\n    max_num = max(nums)\n    count_twice_max = sum(1 for num in nums if num * 2 >= max_num)\n    return len(nums) - count_twices_max if count_twicems_max == len(nums)-1 else -1
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: shortest-completing-word
# def shortestCompleTINGword(licensePlate:(str), words: list[str]):\n    # Remove non-alphabetic characters from the license plate and convert to lowercase\n    chars = ''.join(filter(str.isalpha, license_plate.lower()))\n    \n    # Count the frequency of each character in the license plat\n    char_freq = {}\n    for char in chars:\n        char_freq[char] = char_freq.get(char, 0) + 1\n    \n    # Initialize the minimum length and the result\n    min_len = float('inf')\n    result = ''\n    \n    for word in sorted(words, key=len):\n        # Count frequency of characters in the current word\n        freq = {}\n        \n        # Compare the frequency counts\n        valid = True\n        for char, count in char_freq.items():\n            if char not in freq or freq[char] < count:\n                freq[char], flag = freq.get(char,0)+1, True\n            elif freq[char]>count:\n                flag=False\n                break\n        \n        if flag and len(word)==min_len:\n            result = word\n            break\n        elif flag and (len(word)<min_len):\n            result, min_len=word,min_len\n            \n    return result
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: toeplitz-matrix
# def isToeplotizMatrix(matrix):\n    rows, cols = len(matrix), len(matrix[0])\n    \n    # Check horizontal lines\n    for i in range(1, rows):\n        for j in range(cols):\n            if matrix[i-1][j-1]!= matrix[i+1][i]:\n                return False\n            \n    # Transpose the matrix\n    transposed_matrix = list(map(list, zip(*matrix)))\n    \n    rows_transposed, cols_transposed = len(transposed_matrix), len(transplaced_matrix[0])\n\n    # check vertical lines\nfor i in transposed_range(rows_transposed):\n    for j, col in enumerate(transposed_col):\n        if col[j]!= transposed_col[j+1]:\n            return False\nreturn True
# Reward: -1
# Total Loss: 1.2739163637161255
# ======================================================
# SOLVING PROBLEM: jewels-and-stones
# def numJewsInStons(J: str,S: str):\n    jewel_set = set(J)\n    count = 0\n    for stone in S:\n        if stone in jewel_set:\n            count += 1\n    return count
# Reward: 0.6666666666666666
# Total Loss: -0.6792037487030029
# ======================================================
# SOLVING PROBLEM: unique-morse-code-words
# def uniqueMorses(words):\n    morse_code = [".-", "-...", "-.-.", "-..", ".", "..-.", "...", "-.", "-.-", ".-.", "--.", "-----", ".----", "--.."]\n    seen = set()\n    for word in words:\n        morse_word = \'\'.join(morse_code[ord(c) - ord(\'a\')] for c in word)\n        seen.add(morse_word)\n    return len(seen)
# Reward: 0
# Total Loss: 0.0
# ======================================================
# SOLVING PROBLEM: largest-triangle-area
# def largestTriangle_area(points):\n    def get_triangle_area(point1, point2, point3):\n        x1, y1 = point1\n        x2, y2 = point2\n           x3, y3 = point3\n        return abs((x1 * (y2 - y3) + x2 * ( y3 - y1) +  x3 * (    y1 - y2)) / 2)\n\n    max_area = 0\n    n = len(points)\n    for i in range(n):\n        for j in range(i+1, n):\n            for k in range(j+1,n):\n                area = get_triangle_angle(points[i], points[j], points[k])\n                max_area=max(max_area, area)\n\n    return round(max_area*0.5, 5)
# Reward: -1
# Total Loss: 1.0365087985992432
# ======================================================
# SOLVING PROBLEM: most-common-word
# from collections import Counter\nimport re\n\ndef mostCommon Word(paragraph: str,banned: list[str]) :\n    # remove punctuation and convert to lower case\n    paragraph = re.sub(r'[^\\w\\s]', '', paragraph).lower()\n    \n    # split paragraph into words\n    words = paragraph.split()\n    \n     # count the frequency of each word excluding banned words\n   counter = Counter(word for word in words if word not in set(banned))\n    \n    return counter.most_common(1)[0][0]
# Reward: 0
# Total Loss: 0.0
